# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('testpcosval.csv')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.head()
# Out:
#    PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)    BMI  Blood Group  \
# 0           0          28         44.6        152.0  19.3           15
# 1           0          36         65.0        161.5  24.9           15
# 2           1          33         68.8        165.0  25.3           11
# 3           0          37         65.0        148.0  29.7           13
# 4           0          25         52.0        161.0  20.1           11
#
#    Pulse rate(bpm)   RR (breaths/min)  Hb(g/dl)  Cycle(R/I)  ...  \
# 0                78                22     10.48           2  ...
# 1                74                20     11.70           2  ...
# 2                72                18     11.80           2  ...
# 3                72                20     12.00           2  ...
# 4                72                18     10.00           2  ...
#
#    Hair loss(Y/N)  Pimples(Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)  \
# ...

# %%
df.tail()
# Out:
#      PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)    BMI  Blood Group  \
# 536           0          35         50.0      164.592  18.5           17
# 537           0          30         63.2      158.000  25.3           15
# 538           0          36         54.0      152.000  23.4           13
# 539           0          27         50.0      150.000  22.2           15
# 540           1          23         82.0      165.000  30.1           13
#
#      Pulse rate(bpm)   RR (breaths/min)  Hb(g/dl)  Cycle(R/I)  ...  \
# 536                72                16      11.0           2  ...
# 537                72                18      10.8           2  ...
# 538                74                20      10.8           2  ...
# 539                74                20      12.0           4  ...
# 540                80                20      10.2           4  ...
#
#      Hair loss(Y/N)  Pimples(Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)  \
# ...

# %%
df.isnull().sum()
# Out:
# PCOS (Y/N)              0
#  Age (yrs)              0
# Weight (Kg)             0
# Height(Cm)              0
# BMI                     0
# Blood Group             0
# Pulse rate(bpm)         0
# RR (breaths/min)        0
# Hb(g/dl)                0
# Cycle(R/I)              0
# Cycle length(days)      0
# Pregnant(Y/N)           0
# No. of abortions        0
# Hip(inch)               0
# Waist(inch)             0
# RBS(mg/dl)              0
# Weight gain(Y/N)        0
# hair growth(Y/N)        0
# Skin darkening (Y/N)    0
# Hair loss(Y/N)          0
# Pimples(Y/N)            0
# Reg.Exercise(Y/N)       0
# BP _Systolic (mmHg)     0
# BP _Diastolic (mmHg)    0
# Follicle No. (L)        0
# Follicle No. (R)        0
# Avg. F size (L) (mm)    0
# Avg. F size (R) (mm)    0
# Endometrium (mm)        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# PCOS (Y/N)                2
#  Age (yrs)               29
# Weight (Kg)             117
# Height(Cm)               50
# BMI                     157
# Blood Group               8
# Pulse rate(bpm)          11
# RR (breaths/min)          8
# Hb(g/dl)                 46
# Cycle(R/I)                3
# Cycle length(days)       12
# Pregnant(Y/N)             2
# No. of abortions          6
# Hip(inch)                19
# Waist(inch)              23
# RBS(mg/dl)               55
# Weight gain(Y/N)          2
# hair growth(Y/N)          2
# Skin darkening (Y/N)      2
# Hair loss(Y/N)            2
# Pimples(Y/N)              2
# Reg.Exercise(Y/N)         2
# BP _Systolic (mmHg)       6
# BP _Diastolic (mmHg)      5
# Follicle No. (L)         21
# Follicle No. (R)         20
# Avg. F size (L) (mm)     31
# Avg. F size (R) (mm)     32
# Endometrium (mm)         91
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PCOS (Y/N)            541 non-null    int64
#  1    Age (yrs)            541 non-null    int64
#  2   Weight (Kg)           541 non-null    float64
#  3   Height(Cm)            541 non-null    float64
#  4   BMI                   541 non-null    float64
#  5   Blood Group           541 non-null    int64
#  6   Pulse rate(bpm)       541 non-null    int64
#  7   RR (breaths/min)      541 non-null    int64
#  8   Hb(g/dl)              541 non-null    float64
#  9   Cycle(R/I)            541 non-null    int64
#  10  Cycle length(days)    541 non-null    int64
#  11  Pregnant(Y/N)         541 non-null    int64
#  12  No. of abortions      541 non-null    int64
#  13  Hip(inch)             541 non-null    int64
#  14  Waist(inch)           541 non-null    int64
# ...

# %%
df.describe()
# Out:
#        PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)          BMI  \
# count  541.000000  541.000000   541.000000   541.000000  541.000000
# mean     0.327172   31.430684    59.637153   156.484835   24.307579
# std      0.469615    5.411006    11.028287     6.033545    4.055129
# min      0.000000   20.000000    31.000000   137.000000   12.400000
# 25%      0.000000   28.000000    52.000000   152.000000   21.600000
# 50%      0.000000   31.000000    59.000000   156.000000   24.200000
# 75%      1.000000   35.000000    65.000000   160.000000   26.600000
# max      1.000000   48.000000   108.000000   180.000000   38.900000
#
#        Blood Group  Pulse rate(bpm)   RR (breaths/min)    Hb(g/dl)  \
# count   541.000000        541.000000        541.000000  541.000000
# mean     13.802218         73.247689         19.243993   11.160037
# std       1.840812          4.430285          1.688629    0.866904
# min      11.000000         13.000000         16.000000    8.500000
# ...

# %%
df.shape
# Out:
# (541, 29)

# %%
df.columns
# Out:
# Index(['PCOS (Y/N)', ' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'BMI',
#        'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)',
#        'Cycle(R/I)', 'Cycle length(days)', 'Pregnant(Y/N)', 'No. of abortions',
#        'Hip(inch)', 'Waist(inch)', 'RBS(mg/dl)', 'Weight gain(Y/N)',
#        'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)',
#        'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)',
#        'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)',
#        'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)'],
#       dtype='object')

# %%
object_columns = df.select_dtypes(include=['object']).columns
print("Object_columns:")
print(object_columns)

numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
print("\nNumerical_columns:")
print(numerical_columns)
# Out:
# Object_columns:
# Index([], dtype='object')
#
# Numerical_columns:
# Index(['PCOS (Y/N)', ' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'BMI',
#        'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)',
#        'Cycle(R/I)', 'Cycle length(days)', 'Pregnant(Y/N)', 'No. of abortions',
#        'Hip(inch)', 'Waist(inch)', 'RBS(mg/dl)', 'Weight gain(Y/N)',
#        'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)',
#        'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)',
#        'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)',
#        'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)'],
#       dtype='object')

# %%
def classify_features(df):
    categorical_features = []
    non_categorical_features = []
    discrete_features = []
    continuous_features = []

    for column in df.columns:
        if df[column].dtype == 'object':
            if df[column].nunique() < 5:
                categorical_features.append(column)
            else:
                non_categorical_features.append(column)
        elif df[column].dtype in ['int64']:
            if df[column].nunique() < 5:
                discrete_features.append(column)
            else:
                continuous_features.append(column)

    return categorical_features, non_categorical_features, discrete_features, continuous_features

# %%
categorical, non_categorical, discrete, continuous = classify_features(df)

# %%
print("Categorical Features:", categorical)
print("Non-Categorical Features:", non_categorical)
print("Discrete Features:", discrete)
print("Continuous Features:", continuous)
# Out:
# Categorical Features: []
# Non-Categorical Features: []
# Discrete Features: ['PCOS (Y/N)', 'Cycle(R/I)', 'Pregnant(Y/N)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)', 'Reg.Exercise(Y/N)']
# Continuous Features: [' Age (yrs)', 'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Cycle length(days)', 'No. of abortions', 'Hip(inch)', 'Waist(inch)', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)']

# %%
for i in discrete:
    print(i)
    print(df[i].unique())
    print()
# Out:
# PCOS (Y/N)
# [0 1]
#
# Cycle(R/I)
# [2 4 5]
#
# Pregnant(Y/N)
# [0 1]
#
# Weight gain(Y/N)
# [0 1]
#
# hair growth(Y/N)
# [0 1]
#
# Skin darkening (Y/N)
# [0 1]
#
# Hair loss(Y/N)
# [0 1]
#
# Pimples(Y/N)
# [0 1]
#
# Reg.Exercise(Y/N)
# [0 1]

# %%
for i in discrete:
    plt.figure(figsize=(8, 4))
    ax = sns.countplot(x=i, data=df, palette='hls')

    for p in ax.patches:
        height = p.get_height()
        ax.annotate(f'{height}',
                    xy=(p.get_x() + p.get_width() / 2., height),
                    xytext=(0, 10),
                    textcoords='offset points',
                    ha='center', va='center')

    plt.show()

# %%
for i in discrete:
    plt.figure(figsize=(3,3))
    counts = df[i].value_counts()
    plt.pie(counts, labels=counts.index, autopct='%1.1f%%', colors=['skyblue', 'lightgreen'])
    plt.title(f'Distribution of {i}')
    plt.axis('equal')
    plt.show()

# %%
for i in continuous:
    plt.figure(figsize=(12,6))
    sns.histplot(df[i], bins = 20, kde = True, palette='hls')
    plt.xticks(rotation = 90)
    plt.show()

# %%
for i in continuous:
    plt.figure(figsize=(10, 4))
    sns.boxplot(x=i, data=df, palette='hls')
    plt.xticks(rotation=90)
    plt.show()

# %%
df.columns
# Out:
# Index(['PCOS (Y/N)', ' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'BMI',
#        'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)',
#        'Cycle(R/I)', 'Cycle length(days)', 'Pregnant(Y/N)', 'No. of abortions',
#        'Hip(inch)', 'Waist(inch)', 'RBS(mg/dl)', 'Weight gain(Y/N)',
#        'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)',
#        'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)',
#        'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)',
#        'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)'],
#       dtype='object')

# %%
categorical_features = []
non_categorical_features = []
discrete_features = ['Cycle(R/I)', 'Pregnant(Y/N)', 'Weight gain(Y/N)',
                     'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)',
                     'Pimples(Y/N)', 'Reg.Exercise(Y/N)']
continuous_features = [' Age (yrs)', 'Blood Group', 'Pulse rate(bpm)',
                       'RR (breaths/min)', 'Cycle length(days)', 'No. of abortions',
                       'Hip(inch)', 'Waist(inch)', 'BP _Systolic (mmHg)',
                       'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)']
target = 'PCOS (Y/N)'

# %%
for feature in discrete_features:
    plt.figure(figsize=(10, 4))
    sns.countplot(x=feature, hue=target, data=df, palette='hls')
    plt.title(f'Count plot of {feature} by {target}')
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.legend(title=target, loc='upper right')
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
continuous_features = [' Age (yrs)', 'Blood Group', 'Pulse rate(bpm)',
                       'RR (breaths/min)', 'Cycle length(days)', 'No. of abortions',
                       'Hip(inch)', 'Waist(inch)', 'BP _Systolic (mmHg)',
                       'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)']

# %%
correlation_matrix = df.corr()

# %%
correlation_matrix
# Out:
#                       PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)   \
# PCOS (Y/N)              1.000000   -0.168513     0.211938     0.068254
#  Age (yrs)             -0.168513    1.000000    -0.029734    -0.119819
# Weight (Kg)             0.211938   -0.029734     1.000000     0.420098
# Height(Cm)              0.068254   -0.119819     0.420098     1.000000
# BMI                     0.199697    0.021372     0.901688    -0.006845
# Blood Group             0.036433   -0.010954     0.072682     0.040825
# Pulse rate(bpm)         0.091821    0.045831     0.019983    -0.074339
# RR (breaths/min)        0.036928    0.087382     0.043614    -0.029459
# Hb(g/dl)                0.087170   -0.021558     0.009594     0.024378
# Cycle(R/I)              0.401644   -0.085943     0.200758    -0.017336
# Cycle length(days)     -0.178480    0.055918    -0.002308     0.009536
# Pregnant(Y/N)          -0.027565   -0.044165    -0.051048     0.046365
# ...

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix of Features')
plt.show()

# %%
correlation_with_target = df.corr()[target]

# %%
correlation_with_target
# Out:
# PCOS (Y/N)              1.000000
#  Age (yrs)             -0.168513
# Weight (Kg)             0.211938
# Height(Cm)              0.068254
# BMI                     0.199697
# Blood Group             0.036433
# Pulse rate(bpm)         0.091821
# RR (breaths/min)        0.036928
# Hb(g/dl)                0.087170
# Cycle(R/I)              0.401644
# Cycle length(days)     -0.178480
# Pregnant(Y/N)          -0.027565
# No. of abortions       -0.057158
# Hip(inch)               0.162297
# Waist(inch)             0.164598
# RBS(mg/dl)              0.048922
# Weight gain(Y/N)        0.441047
# hair growth(Y/N)        0.464667
# Skin darkening (Y/N)    0.475733
# Hair loss(Y/N)          0.172879
# Pimples(Y/N)            0.286077
# Reg.Exercise(Y/N)       0.065337
# BP _Systolic (mmHg)     0.007942
# BP _Diastolic (mmHg)    0.038032
# Follicle No. (L)        0.603346
# Follicle No. (R)        0.648327
# Avg. F size (L) (mm)    0.132992
# Avg. F size (R) (mm)    0.097690
# ...

# %%
plt.figure(figsize=(16, 6))
sns.barplot(x=correlation_with_target.index, y=correlation_with_target.values, palette='coolwarm')
plt.title('Correlation of Features with DEATH_EVENT')
plt.ylabel('Correlation Coefficient')
plt.xlabel('Features')
plt.xticks(rotation=45)
plt.show()

# %%
df.columns
# Out:
# Index(['PCOS (Y/N)', ' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'BMI',
#        'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)',
#        'Cycle(R/I)', 'Cycle length(days)', 'Pregnant(Y/N)', 'No. of abortions',
#        'Hip(inch)', 'Waist(inch)', 'RBS(mg/dl)', 'Weight gain(Y/N)',
#        'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)',
#        'Pimples(Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)',
#        'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)',
#        'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)'],
#       dtype='object')

# %%
pivot_table = pd.pivot_table(df,
                             index='Weight (Kg)',
                             columns='Cycle(R/I)',
                             values='PCOS (Y/N)',
                             aggfunc='mean',
                             fill_value=0)

# %%
cross_tabulation_table = pd.crosstab(df['PCOS (Y/N)'], df['Cycle(R/I)'])
print("Cross-tabulation of 'PCOS' and 'cycle(R/i)':\n", cross_tabulation_table)
# Out:
# Cross-tabulation of 'PCOS' and 'cycle(R/i)':
#  Cycle(R/I)    2   4  5
# PCOS (Y/N)
# 0           308  56  0
# 1            82  94  1

# %%
df_new =df.copy()

# %%
X = df_new.drop('PCOS (Y/N)', axis=1)
y = df_new['PCOS (Y/N)']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify = y, random_state=42)

# %%
df.shape
# Out:
# (541, 29)

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE()
X_re_train, y_re_train = smote.fit_resample(X_train, y_train)
